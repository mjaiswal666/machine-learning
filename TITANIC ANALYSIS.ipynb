# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("titanic3.xls")
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
def NullAnalysis(df):
    AllNull=df.isnull().values.all(axis=0)
    columnnames=df.columns
    Nulldf=pd.DataFrame({'ColumnsNames':columnnames,'AllNull':AllNull})
    return Nulldf

# %%
dfnull=NullAnalysis(df)
dfnull
# Out:
#    ColumnsNames  AllNull
# 0        pclass    False
# 1      survived    False
# 2          name    False
# 3           sex    False
# 4           age    False
# 5         sibsp    False
# 6         parch    False
# 7        ticket    False
# 8          fare    False
# 9         cabin    False
# 10     embarked    False
# 11         boat    False
# 12         body    False
# 13    home.dest    False

# %%
dfAnalysis=df.isnull().sum()
dfAnalysis
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.drop(["cabin","body","name","home.dest"],axis=1,inplace=True)
df
# Out:
#       pclass  survived     sex      age  sibsp  parch            ticket  \
# 0          1         1  female  29.0000      0      0             24160
# 1          1         1    male   0.9167      1      2            113781
# 2          1         0  female   2.0000      1      2            113781
# 3          1         0    male  30.0000      1      2            113781
# 4          1         0  female  25.0000      1      2            113781
# 5          1         1    male  48.0000      0      0             19952
# 6          1         1  female  63.0000      1      0             13502
# 7          1         0    male  39.0000      0      0            112050
# 8          1         1  female  53.0000      2      0             11769
# 9          1         0    male  71.0000      0      0          PC 17609
# 10         1         0    male  47.0000      1      0          PC 17757
# 11         1         1  female  18.0000      1      0          PC 17757
# ...

# %%
dfAnalysis=df.isnull().sum()
dfAnalysis
# Out:
# pclass        0
# survived      0
# sex           0
# age         263
# sibsp         0
# parch         0
# ticket        0
# fare          1
# embarked      2
# boat        823
# dtype: int64

# %%
colnames=[i for i in df.columns]
datatype=[i for i in df.dtypes]
dfAnalysis=[i for i in df.isnull().sum()]
dfDataType=pd.DataFrame({'ColumnNames':colnames,'Data Types':datatype,'Total Null':dfAnalysis})
dfDataType
# Out:
#   ColumnNames Data Types  Total Null
# 0      pclass      int64           0
# 1    survived      int64           0
# 2         sex     object           0
# 3         age    float64         263
# 4       sibsp      int64           0
# 5       parch      int64           0
# 6      ticket     object           0
# 7        fare    float64           1
# 8    embarked     object           2
# 9        boat     object         823

# %%
#dataframe=Analysis(df)
def ReplaceNull(dataframe,df):
    for index,rows in dataframe.iterrows():
        #float64
        if(rows['Data Types']=='float64' and rows['Total Null Values']>0):
            columnname=rows['ColumnNames']
            print('********************',columnname)
            df1[columnname].fillna(np.mean(df[columnname]),inplace=True)
            print(columnname,'value replace by mean')
        #object
        if(rows['Data Types']=='object' and rows['Total Null Values']>0):
            columnname=rows['ColumnNames']
            print('********************',columnname)
            df1[columnname].fillna((df[columnname].mode())[0],inplace=True)
            print(columnname,'value replce by mode')
        #print(Analysis(df))
    return df

# %%
dfAnalysis=df.isnull().sum()
dfAnalysis
# Out:
# pclass        0
# survived      0
# sex           0
# age         263
# sibsp         0
# parch         0
# ticket        0
# fare          1
# embarked      2
# boat        823
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
df['sex']=labelencoder.fit_transform(df.loc[:,['sex']].astype(str))
df['ticket']=labelencoder.fit_transform(df.loc[:,['ticket']].astype(str))
df['embarked']=labelencoder.fit_transform(df.loc[:,['embarked']].astype(str))
df['boat']=labelencoder.fit_transform(df.loc[:,['boat']].astype(str))
df['age']=labelencoder.fit_transform(df.loc[:,['age']].astype(str))
df['fare']=labelencoder.fit_transform(df.loc[:,['fare']].astype(str))
# Out:
# C:\New folder\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\New folder\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\New folder\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfAnalysis=df.isnull().sum()
dfAnalysis
# Out:
# pclass      0
# survived    0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    0
# boat        0
# dtype: int64

# %%
df.head()
# Out:
#    pclass  survived  sex  age  sibsp  parch  ticket  fare  embarked  boat
# 0       1         1    0   37      0      0     187    77         2    11
# 1       1         1    1    6      1      2      49    56         2     2
# 2       1         0    0   21      1      2      49    56         2    27
# 3       1         0    1   39      1      2      49    56         2    27
# 4       1         0    0   31      1      2      49    56         2    27

# %%
df.shape
# Out:
# (1309, 10)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'embarked', 'boat'],
#       dtype='object')

# %%
#ALALYSIS

df.describe()
# Out:
#             pclass     survived          sex          age        sibsp  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.644003    52.851795     0.498854
# std       0.837836     0.486055     0.478997    29.269120     1.041658
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000    29.000000     0.000000
# 50%       3.000000     0.000000     1.000000    45.000000     0.000000
# 75%       3.000000     1.000000     1.000000    79.000000     1.000000
# max       3.000000     1.000000     1.000000    98.000000     8.000000
#
#              parch       ticket         fare     embarked         boat
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean      0.385027   463.625668   140.199389     1.495034    21.576776
# std       0.865560   278.069490    82.291777     0.816130     8.485711
# ...

# %%
#CORRELATION

corr = df[['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
       'embarked', 'boat']].corr()
corr
# Out:
#             pclass  survived       sex       age     sibsp     parch  \
# pclass    1.000000 -0.312469  0.124617 -0.021256  0.060832  0.018322
# survived -0.312469  1.000000 -0.528693 -0.081464 -0.027825  0.082660
# sex       0.124617 -0.528693  1.000000  0.062981 -0.109609 -0.213125
# age      -0.021256 -0.081464  0.062981  1.000000 -0.005046 -0.031575
# sibsp     0.060832 -0.027825 -0.109609 -0.005046  1.000000  0.373587
# parch     0.018322  0.082660 -0.213125 -0.031575  0.373587  1.000000
# ticket    0.309695 -0.125869  0.024725 -0.002742  0.063921  0.053389
# fare      0.270651 -0.097246  0.110029  0.034113 -0.083750 -0.142964
# embarked  0.182154 -0.172526  0.095215 -0.138294  0.064519  0.043835
# boat      0.235431 -0.799905  0.429185  0.101928  0.007383 -0.101247
#
#             ticket      fare  embarked      boat
# pclass    0.309695  0.270651  0.182154  0.235431
# survived -0.125869 -0.097246 -0.172526 -0.799905
# sex       0.024725  0.110029  0.095215  0.429185
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,12))            
sns.heatmap(corr,annot=True,fmt=".2f")

# %%
sns.pairplot(df)

# %%
from mpl_toolkits.mplot3d import Axes3D
Axes3D = Axes3D  
fig =  plt.figure(figsize=(8,8))
ax= fig.add_subplot(111,projection='3d')

xs=df['survived']
ys=df['sex']
zs=df['boat']

ax.scatter(xs,ys,zs,s=50,alpha=0.6,edgecolors='w')
ax.set_xlabel('Survived')
ax.set_ylabel('Sex')
ax.set_zlabel('Boat')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
Axes3D = Axes3D  
fig =  plt.figure(figsize=(8,8))
ax= fig.add_subplot(111,projection='3d')

xs=df['survived']
ys=df['sex']
zs=df['age']

ax.scatter(xs,ys,zs,s=50,alpha=0.6,edgecolors='w')
ax.set_xlabel('Survived')
ax.set_ylabel('Sex')
ax.set_zlabel('age')

plt.show()

# %%
df.head()
# Out:
#    pclass  survived  sex  age  sibsp  parch  ticket  fare  embarked  boat
# 0       1         1    0   37      0      0     187    77         2    11
# 1       1         1    1    6      1      2      49    56         2     2
# 2       1         0    0   21      1      2      49    56         2    27
# 3       1         0    1   39      1      2      49    56         2    27
# 4       1         0    0   31      1      2      49    56         2    27

# %%
df['age']=np.log(df['age'])**2
df['ticket']=np.log(df['ticket'])**2
sns.relplot(x='age',y='ticket',hue='survived',data=df)

# %%
x = df.mean
x

# %%
dfScale=df**8

# %%
sns.relplot(x='age',y='ticket',hue='survived',data=dfScale)

# %%
dfTrans=df*0.5+5

# %%
sns.relplot(x='age',y='ticket',hue='survived',data=dfTrans)

# %%
for i in df.columns:
    print(i)
    print(np.var(df[i]))

# %%
X=[]
for i,j in df.iterrows():
    X.append([j['pclass'],j['survived'],j['sex'],j['age'],j['sibsp'],j['parch'],j['fare'],j['embarked'],j['boat']])

# %%
labelencoder = LabelEncoder()
tf = labelencoder.fit(df['survived'])
Y=labelencoder.fit_transform(df['survived'])

# %%
Y

# %%
X

# %%
plt.plot(X)

# %%
df.columns

# %%
import seaborn as sns

# %%
df

# %%
#ax = sns.relplot(x='age',y='ticket',hue='survived',data=df)

# %%
df['age']=np.log(df['age'])**2
df['ticket']=np.log(df['ticket'])**2
sns.relplot(x='age',y='ticket',hue='survived',data=df)
# Out:
# C:\New folder\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\New folder\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
